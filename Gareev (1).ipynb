# %% [markdown]
# # Video Game Sales

# %% [markdown]
# ### Подключение библиотек

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Загрузка данных

# %%
vgs = pd.read_csv(r'C:\Users\Рустам\Desktop\vgsales.csv')

# %%
# Out:
# (12819, 11)

# %%
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %% [markdown]
# #### Описание данных

# %% [markdown]
# Этот набор данных содержит список видеоигр, продажи которых превысили 100 000 копий.
#
# Name - Название игры
#
# Platform - Платформа выпуска игр (например, PC, PS4 и т.д.)
#
# Year - Год выпуска игры
#
# Genre - Жанр игры
#
# Publisher - Издатель игры
#
# NA_Sales - Продажи в Северной Америке (в миллионах)
#
# EU_Sales - Продажи в Европе (в миллионах)
#
# JP_Sales - Продажи в Японии (в миллионах)
#
# Other_Sales - Продажи в остальном мире (в миллионах)
#
# Global_Sales - Общий объем продаж по всему миру.

# %% [markdown]
# ##### Выведите размерность и краткую информацию о наборе данных

# %%
vgs.shape
# Out:
# (12819, 11)

# %%
# Out:
# (16598, 11)

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12819 entries, 0 to 12818
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          12819 non-null  int64
#  1   Name          12819 non-null  object
#  2   Platform      12819 non-null  object
#  3   Year          12616 non-null  float64
#  4   Genre         12819 non-null  object
#  5   Publisher     12783 non-null  object
#  6   NA_Sales      12818 non-null  float64
#  7   EU_Sales      12818 non-null  float64
#  8   JP_Sales      12818 non-null  float64
#  9   Other_Sales   12818 non-null  float64
#  10  Global_Sales  12818 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
vgs.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Выведите краткую статистическую информацию по набору данных

# %%
vgs.describe()
# Out:
#               Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  12819.00000  12616.000000  12818.000000  12818.000000  12818.000000
# mean    6410.94906   2005.919388      0.339915      0.187966      0.097431
# std     3700.75463      5.994138      0.915835      0.568481      0.349437
# min        1.00000   1980.000000      0.000000      0.000000      0.000000
# 25%     3206.50000   2002.000000      0.050000      0.000000      0.000000
# 50%     6411.00000   2007.000000      0.130000      0.040000      0.000000
# 75%     9615.50000   2010.000000      0.320000      0.160000      0.060000
# max    12820.00000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  12818.000000  12818.000000
# mean       0.062000      0.687387
# std        0.212602      1.741401
# min        0.000000      0.060000
# 25%        0.010000      0.130000
# 50%        0.020000      0.270000
# 75%        0.050000      0.630000
# max       10.570000     82.740000

# %%
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %% [markdown]
# ##### Проверьте набор данных на наличие пропущенных и дублирующих значений

# %%
vgs.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            203
# Genre             0
# Publisher        36
# NA_Sales          1
# EU_Sales          1
# JP_Sales          1
# Other_Sales       1
# Global_Sales      1
# dtype: int64

# %%
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
print(vgs.duplicated().sum())
# Out:
# 0

# %%
# Out:
# 0

# %% [markdown]
# #### Напишите краткий вывод о наборе данных

# %%
vgs.shape[0]
# Out:
# 12819

# %% [markdown]
# ### Заполнение пустых записей

# %% [markdown]
# Удалите пропущенные значения по признаку Publisher, а по признаку Year - замените на среднее значение. Значения по полю Year преобразуйте в целый тип. Удалите признак Rank. После преобразований, убедитесь, что изменения сохранились в наборе данных.

# %%
vgs_clean = vgs.dropna(subset=['Publisher'])

# %%
mean_year = vgs_clean['Year'].mean()
vgs_clean.loc[:, 'Year'] = vgs_clean['Year'].fillna(mean_year).astype(int)

# %%
vgs_clean = vgs_clean.drop('Rank', axis=1)

# %%
vgs_clean.head()
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
vgs.head()
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
vgs_clean.isnull().sum()
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        1
# EU_Sales        1
# JP_Sales        1
# Other_Sales     1
# Global_Sales    1
# dtype: int64

# %%
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
vgs_clean.shape
# Out:
# (12783, 10)

# %%
# Out:
# (16540, 10)

# %%
vgs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12783 entries, 0 to 12818
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          12783 non-null  object
#  1   Platform      12783 non-null  object
#  2   Year          12783 non-null  int64
#  3   Genre         12783 non-null  object
#  4   Publisher     12783 non-null  object
#  5   NA_Sales      12782 non-null  float64
#  6   EU_Sales      12782 non-null  float64
#  7   JP_Sales      12782 non-null  float64
#  8   Other_Sales   12782 non-null  float64
#  9   Global_Sales  12782 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16540 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16540 non-null  object
#  1   Platform      16540 non-null  object
#  2   Year          16540 non-null  int32
#  3   Genre         16540 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16540 non-null  float64
#  6   EU_Sales      16540 non-null  float64
#  7   JP_Sales      16540 non-null  float64
#  8   Other_Sales   16540 non-null  float64
#  9   Global_Sales  16540 non-null  float64
# dtypes: float64(5), int32(1), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Анализ продаж видеоигр

# %% [markdown]
# #### 1. В каком году было выпущено больше всего игр? Выведите первые 10 записей.

# %%
top_years = vgs_clean['Year'].value_counts().head(10)
print(top_years)
# Out:
# Year
# 2008    1088
# 2009    1083
# 2005     968
# 2010     935
# 2011     877
# 2007     877
# 2006     670
# 2002     667
# 2003     626
# 2004     621
# Name: count, dtype: int64

# %%
# Out:
# Year
# 2007    1450
# 2009    1431
# 2008    1428
# 2010    1257
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 5))
top_years.plot(kind='bar')
plt.show()

# %%
print(f"\nКоличество уникальных платформ: {vgs_clean['Platform'].nunique()}")
print(f"Количество уникальных жанров: {vgs_clean['Genre'].nunique()}")
print(f"Количество уникальных издателей: {vgs_clean['Publisher'].nunique()}")
# Out:
# Количество уникальных платформ: 29
# Количество уникальных жанров: 12
# Количество уникальных издателей: 425

# %%
# Out:
# Количество уникальных значений в Platform: 31
# Количество уникальных значений в Genre: 12
# Количество уникальных значений в Publisher: 578

# %%
plt.figure(figsize=(14,8))
plt.scatter(vgs["Year"],vgs["Global_Sales"])
plt.xlabel('Year')
plt.ylabel('Global_Sales')
plt.show()

# %%
# Scatterplot

# %% [markdown]
# #### 2. Получите среднюю стоимость продаж в Европе

# %%
print(vgs_clean["EU_Sales"].mean())
# Out:
# 0.1881411359724613

# %%
# Out:
# 0.1468833131801693

# %% [markdown]
# #### 3. Получите максимальную стоимость продаж в Японии и вывведите полную информацию об игре с максимальной суммой продаж

# %%
maxJapan = vgs_clean["JP_Sales"].max()
print(maxJapan)
# Out:
# 10.22

# %%
gameMax = vgs_clean[vgs_clean["JP_Sales"] == maxJapan]
gameMax
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4      8.89     10.22          1.0         31.37

# %%
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4      8.89     10.22          1.0         31.37

# %% [markdown]
# ##### Выведите первые 10 записей с максимальными суммами продажам в Японии по годам

# %%
japan_sales_by_year = vgs.groupby('Year')['JP_Sales'].sum().sort_values(ascending=False).head(10)
top_10_japan_sales = japan_sales_by_year.head(10).reset_index()
top_10_japan_sales
# Out:
#      Year  JP_Sales
# 0  2006.0     69.98
# 1  2009.0     58.43
# 2  1996.0     56.88
# 3  2007.0     56.65
# 4  2008.0     56.20
# 5  2010.0     55.18
# 6  2005.0     53.86
# 7  1999.0     52.17
# 8  1998.0     49.60
# 9  2011.0     49.56

# %%
# Out:
#    Year  JP_Sales
# 0  2006     73.73
# 1  2007     66.11
# 2  2009     61.89
# 3  2008     60.26
# 4  2010     59.49
# 5  1996     57.44
# 6  2005     54.28
# 7  2011     53.04
# 8  1999     52.34
# 9  2012     51.74

# %% [markdown]
# #### 4. К какому жанру относится видеоигра "Brain Age 2: More Training in Minutes a Day" video game?

# %%
res = vgs[vgs['Name'] == 'Brain Age 2: More Training in Minutes a Day']['Genre']
res
# Out:
# 27    Puzzle
# Name: Genre, dtype: object

# %%
# Out:
# 27    Puzzle
# Name: Genre, dtype: object

# %% [markdown]
# #### 5.  Каков объём продаж видеоигры «Grand Theft Auto: Vice City» по всему миру?

# %%
res = vgs[vgs['Name'] == 'Grand Theft Auto: Vice City']['Global_Sales']
print(res)
# Out:
# 24    16.15
# Name: Global_Sales, dtype: float64

# %%
# Out:
# 24       16.15
# 13732     0.04
# Name: Global_Sales, dtype: float64

# %%
vgs[vgs['Name'] == 'Grand Theft Auto: Vice City']
# Out:
#                            Name Platform    Year   Genre  \
# 24  Grand Theft Auto: Vice City      PS2  2002.0  Action
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 24  Take-Two Interactive      8.41      5.49      0.47         1.78
#
#     Global_Sales
# 24         16.15

# %%
# Out:
#                               Name Platform  Year   Genre  \
# 24     Grand Theft Auto: Vice City      PS2  2002  Action
# 13732  Grand Theft Auto: Vice City       PC  2003  Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 24     Take-Two Interactive      8.41      5.49      0.47         1.78
# 13732  Take-Two Interactive      0.00      0.03      0.00         0.01
#
#        Global_Sales
# 24            16.15
# 13732          0.04

# %% [markdown]
# #### 6. Выведите название видеоигры, которая имеет самые высокие продажи в Северной Америке.

# %%
res = vgs[vgs['NA_Sales'] == vgs['NA_Sales'].max()]['Name']
res
# Out:
# 0    Wii Sports
# Name: Name, dtype: object

# %%
# Out:
# 0    Wii Sports
# Name: Name, dtype: object

# %% [markdown]
# #### 7. Выведите видеоигры с самыми низкими продажами в мире

# %%
low = vgs[["Global_Sales", "Name"]].groupby('Name').sum().reset_index()
low.sort_values("Global_Sales").head(10)
# Out:
#                                                  Name  Global_Sales
# 1490                       Death Jr. II: Root of Evil          0.00
# 77    A llI S.V.: A Ressha de Gyoukou 3 Super Version          0.06
# 2955      Hajime no Ippo Portable: Victorious Spirits          0.06
# 5849                             Racing Gears Advance          0.06
# 2056            ESPN International Winter Sports 2002          0.06
# 454                       Backyard Skateboarding 2006          0.06
# 450                         Backyard NFL Football '08          0.06
# 3775                          Klonoa Beach Volleyball          0.06
# 7036                                   Summon Night 2          0.06
# 491               Barbie and Her Sisters Puppy Rescue          0.06

# %%
# Out:
#                                                     Name  Global_Sales
# 15980                                              Turok          0.01
# 15981                     Coven and Labyrinth of Refrain          0.01
# 15982  Super Battle For Money Sentouchuu: Kyuukyoku n...          0.01
# 15983                                   Dragon Zakura DS          0.01
# 15984                             Chameleon: To Dye For!          0.01
# ...                                                  ...           ...
# 16593                 Woody Woodpecker in Crazy Castle 5          0.01
# 16594                      Men in Black II: Alien Escape          0.01
# 16595   SCORE International Baja 1000: The Official Game          0.01
# 16596                                         Know How 2          0.01
# 16597                                   Spirits & Spells          0.01
#
# [610 rows x 2 columns]

# %% [markdown]
# #### 8. Игр какого жанра было создано больше всего?

# %%
vgs["Genre"].nunique()
# Out:
# 12

# %%
# Out:
# 12

# %%
vgs["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
vgs["Genre"].value_counts()
# Out:
# Genre
# Action          2652
# Sports          1992
# Misc            1349
# Role-Playing    1175
# Shooter         1063
# Racing           995
# Platform         752
# Fighting         710
# Simulation       649
# Adventure        647
# Strategy         441
# Puzzle           394
# Name: count, dtype: int64

# %%
# Out:
# Genre
# Action          3309
# Sports          2343
# Misc            1712
# Role-Playing    1486
# Shooter         1308
# Adventure       1282
# Racing          1248
# Platform         884
# Simulation       863
# Fighting         846
# Strategy         678
# Puzzle           581
# Name: count, dtype: int64

# %%
genre_counts = vgs['Genre'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='rocket')
# Out:
# C:\Users\Рустам\AppData\Local\Temp\ipykernel_14884\1668560673.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='rocket')
# <Axes: xlabel='Genre'>

# %% [markdown]
# #### 9. Лучшие игры за 5 лет выпуска по жанрам

# %%
selected_years = [2007, 2008, 2009, 2010, 2011]
vgs_selected = vgs[vgs['Year'].isin(selected_years)]

# Находим самые продаваемые игры по жанрам для каждого года
best_games = vgs_selected.groupby(['Year', 'Genre']).apply(lambda x: x.nlargest(1, 'Global_Sales')).reset_index(drop=True)

# Строим график
plt.figure(figsize=(12,6))
sns.barplot(x='Year', y='Global_Sales', hue='Genre', data=best_games, palette='pastel')

plt.title('Best Selling Game by Genre (2007-2011)')
plt.xlabel('Year')
plt.ylabel('Global Sales (millions)')
plt.xticks(rotation=45)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Рустам\AppData\Local\Temp\ipykernel_14884\3377395207.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_games = vgs_selected.groupby(['Year', 'Genre']).apply(lambda x: x.nlargest(1, 'Global_Sales')).reset_index(drop=True)

# %% [markdown]
# #### 10.  В каком году были самые высокие продажи по всему миру?¶

# %%
data_year =vgs_clean.groupby('Year')['Global_Sales'].sum().sort_values(ascending=False)
data_year.head(10)
# Out:
# Year
# 2008    669.58
# 2009    657.37
# 2007    601.00
# 2010    591.20
# 2005    545.61
# 2006    511.20
# 2011    508.22
# 2004    410.06
# 2002    390.53
# 2013    364.37
# Name: Global_Sales, dtype: float64

# %%
data_year.head(10)
# Out:
#    index                       Name Platform  Year         Genre Publisher  \
# 0      0                 Wii Sports      Wii  2006        Sports  Nintendo
# 1      1          Super Mario Bros.      NES  1985      Platform  Nintendo
# 2      2             Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3      3          Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4      4   Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
# 5      5                     Tetris       GB  1989        Puzzle  Nintendo
# 6      6      New Super Mario Bros.       DS  2006      Platform  Nintendo
# 7      7                   Wii Play      Wii  2006          Misc  Nintendo
# 8      8  New Super Mario Bros. Wii      Wii  2009      Platform  Nintendo
# 9      9                  Duck Hunt      NES  1984       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %% [markdown]
# #### 11. Игры какого жанра имеют самую высокую цену продажи в мире

# %% [markdown]
# #### 12. На какой платформе самая высокая цена продажи в мире?

# %% [markdown]
# #### 13. Выведите топ 20 Publisher

# %%
top_20_publishers = vgs_clean['Publisher'].value_counts().head(20)

plt.figure(figsize=(12, 8))
plt.bar(top_20_publishers.index, top_20_publishers.values, align='center', width=0.5)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()

# %% [markdown]
# #### 14. Общий доход по регионам

# %%
vgsfweijgowhiugwrogiwgwjnd
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16540 rows x 10 columns]

# %%
cbclbihocxbjnbmws
# Out:
#         region     sale
# 0     NA_Sales  4384.41
# 1     EU_Sales  2429.45
# 2     JP_Sales  1290.09
# 3  Other_Sales   797.08

# %%
# Out:
# <Axes: xlabel='region', ylabel='sale'>

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### 15.Pair plot

# %%
# Out:
#        Year Platform         Genre  NA_Sales  EU_Sales  Other_Sales
# 0      2006      Wii        Sports     41.49     29.02         8.46
# 1      1985      NES      Platform     29.08      3.58         0.77
# 2      2008      Wii        Racing     15.85     12.88         3.31
# 3      2009      Wii        Sports     15.75     11.01         2.96
# 4      1996       GB  Role-Playing     11.27      8.89         1.00
# ...     ...      ...           ...       ...       ...          ...
# 16593  2002      GBA      Platform      0.01      0.00         0.00
# 16594  2003       GC       Shooter      0.01      0.00         0.00
# 16595  2008      PS2        Racing      0.00      0.00         0.00
# 16596  2010       DS        Puzzle      0.00      0.01         0.00
# 16597  2003      GBA      Platform      0.01      0.00         0.00
#
# [16540 rows x 6 columns]

# %% [markdown]
# #### 16. Выведите 3 самых распространенных жанра видеоигр в мире

# %%
vgs['Genre'].value_counts().head(3)
# Out:
# Genre
# Action    2652
# Sports    1992
# Misc      1349
# Name: count, dtype: int64

# %%
# Out:
# Genre
# Action    3309
# Sports    2343
# Misc      1712
# Name: count, dtype: int64

# %% [markdown]
# ### 17. В названиях скольких видеоигр есть слово «super» ??

# %%
# Out:
# 287
