# %% [markdown]
# 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Import the dataset chipotle.tsv

# %% [markdown]
# 3. Assign it to a variable called chipo

# %%
chipo=pd.read_csv("chipotle.tsv", sep = "\t")

# %% [markdown]
# 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# 5. What is the number of observations in the dataset?

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# 6. What is the number of columns in the dataset?

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# 7. Print the name of all the columns

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# 9. Which was the most-ordered item?

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipo.describe(include="object")
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %%
chipo.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
chipo[['item_name','order_id','quantity']].groupby("item_name").sum()
# Out:
#                                        order_id  quantity
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# ...

# %%
most_order=chipo[['item_name','order_id','quantity']].groupby("item_name").sum()
most_order
most_order.sort_values("quantity",ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [raw]
# most_order=chipo[['choice_description','order_id','quantity']].groupby("item_name").sum()
# most_order
# most_order.sort_values("quantity",ascending=False).head(1)

# %% [markdown]
# most_order

# %%
most_order=chipo[['choice_description','order_id','quantity']].groupby("choice_description").sum()
most_order
most_order.sort_values("quantity",ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# 11. What was the most ordered item in the choice_description column?

# %%
most_order=chipo[['choice_description','order_id','quantity']].groupby("choice_description").sum()
most_order
most_order.sort_values("quantity",ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# 12. How many items were orderd in total?

# %%
chipo["quantity"].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# 13. Turn the item price into a float

# %% [markdown]
# a. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('O')

# %%
print(chipo["item_price"].dtype)
# Out:
# float64

# %% [markdown]
# b. Create a lambda function and change the type of item price

# %%
chipo["item_price"] = chipo["item_price"].apply(lambda x: float(x[1:]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 chipo["item_price"] = chipo["item_price"].apply(lambda x: float(x[1:]))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chipo['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# c. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
total_revenue = chipo['revenue'].sum()

# %%
total_revenue
# Out:
# np.float64(39237.02)

# %% [markdown]
# 15. How many orders were made in the period?

# %%
# Out:
# 1834

# %%
orders = chipo["order_id"].nunique()

# %%
orders
# Out:
# 1834

# %%
chipo[chipo["order_id"]==926]
# Out:
#       order_id  quantity           item_name  \
# 2304       926         1       Steak Burrito
# 2305       926         1        Chicken Bowl
# 2306       926         1        Chicken Bowl
# 2307       926         1        Chicken Bowl
# 2308       926         1          Steak Bowl
# 2309       926         1        Chicken Bowl
# 2310       926         1       Steak Burrito
# 2311       926         1     Chicken Burrito
# 2312       926         1        Chicken Bowl
# 2313       926         1        Chicken Bowl
# 2314       926         1  Chicken Salad Bowl
# 2315       926         1          Steak Bowl
# 2316       926         1     Chicken Burrito
# 2317       926         1          Steak Bowl
# 2318       926         1        Chicken Bowl
# 2319       926         1          Steak Bowl
# 2320       926         1     Chicken Burrito
# 2321       926         1        Chicken Bowl
# 2322       926         1        Chicken Bowl
# 2323       926         1    Barbacoa Burrito
# ...

# %%
chipo['order_id'].value_counts().count()
# Out:
# np.int64(1834)

# %% [markdown]
# 16. What is the average revenue amount per order?

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# 2                                            [Apple]        3.39     3.39
# 3                                                NaN        2.39     2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96

# %%
revenue_per_order = chipo.groupby('order_id')['revenue'].sum()

average_revenue_per_order = revenue_per_order.mean()
print(average_revenue_per_order)
# Out:
# 21.39423118865867

# %%
chipo.groupby(['order_id'])['revenue'].sum().mean()
# Out:
# np.float64(21.39423118865867)

# %%
chipo[['item_price','order_id','quantity']].groupby(['order_id']).mean()
# Out:
#           item_price  quantity
# order_id
# 1           2.890000       1.0
# 2          16.980000       2.0
# 3           6.335000       1.0
# 4          10.500000       1.0
# 5           6.850000       1.0
# ...              ...       ...
# 1830       11.500000       1.0
# 1831        4.300000       1.0
# 1832        6.600000       1.0
# 1833       11.750000       1.0
# 1834        9.583333       1.0
#
# [1834 rows x 2 columns]

# %% [markdown]
# 17. How many different items are sold?

# %%
chipo['item_name'].value_counts().count()
# Out:
# np.int64(50)

# %%
items_sold = chipo['item_name'].nunique()
items_sold
# Out:
# 50

# %% [markdown]
# 18. How many products cost more than $10.00?

# %%
expensive_items = chipo[chipo['item_price'] > 10.00]

products = expensive_items['item_name'].nunique()
products
# Out:
# 31

# %% [markdown]
# 19. What is the price of each item?

# %%
unique_items=chipo['item_name'].nunique()

# %%
unique_items
# Out:
# 50

# %%
chipo[['item_name','item_price']].groupby('item_name').mean()
# Out:
#                                        item_price
# item_name
# 6 Pack Soft Drink                        6.610185
# Barbacoa Bowl                           10.187273
# Barbacoa Burrito                         9.832418
# Barbacoa Crispy Tacos                   10.928182
# Barbacoa Salad Bowl                     10.640000
# Barbacoa Soft Tacos                     10.018400
# Bottled Water                            1.867654
# Bowl                                    14.800000
# Burrito                                  7.400000
# Canned Soda                              1.320577
# Canned Soft Drink                        1.457641
# Carnitas Bowl                           10.833971
# Carnitas Burrito                        10.132712
# Carnitas Crispy Tacos                   11.137143
# Carnitas Salad                           8.990000
# Carnitas Salad Bowl                     11.056667
# Carnitas Soft Tacos                      9.398500
# Chicken Bowl                            10.113953
# ...

# %%
len(chipo[['item_name','item_price']].groupby('item_name').mean())
# Out:
# 50

# %% [markdown]
# 20. Sort by the name of the item

# %%
sorted_chipo = chipo.sort_values(by='item_name')
print(sorted_chipo[['item_name', 'quantity', 'item_price']].head(10))
# Out:
#               item_name  quantity item_price
# 3389  6 Pack Soft Drink         2    $12.98
# 341   6 Pack Soft Drink         1     $6.49
# 1849  6 Pack Soft Drink         1     $6.49
# 1860  6 Pack Soft Drink         1     $6.49
# 2713  6 Pack Soft Drink         1     $6.49
# 3422  6 Pack Soft Drink         1     $6.49
# 553   6 Pack Soft Drink         1     $6.49
# 1916  6 Pack Soft Drink         1     $6.49
# 1922  6 Pack Soft Drink         1     $6.49
# 1937  6 Pack Soft Drink         1     $6.49

# %% [markdown]
# 21. What was the quantity of the most expensive item ordered?

# %%
if 'revenue' not in chipo.columns:
    chipo['revenue'] = chipo['quantity'] * chipo['item_price']

most_expensive_row = chipo.loc[chipo['item_price'].idxmax()]

chipo.loc[[chipo['item_price'].idxmax()]]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  revenue
# 3598       44.25   663.75

# %%
chipo[['quantity','item_name','item_price']].max()
# Out:
# quantity                     15
# item_name     Veggie Soft Tacos
# item_price                44.25
# dtype: object

# %%
max(chipo['quantity'])
# Out:
# 15

# %%
chipo[chipo['quantity']==chipo['quantity'].max()]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  revenue
# 3598       44.25   663.75

# %% [markdown]
# 22. How many times was a Veggie Salad Bowl ordered?

# %%
count = chipo[chipo['item_name'] == 'Veggie Salad Bowl'].shape[0]
count
# Out:
# 18

# %% [markdown]
# 23. How many times did someone order more than one Canned Soda?

# %%
filtered_table = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]
print(filtered_table.to_string(index=True))
# Out:
#       order_id  quantity    item_name choice_description item_price                   revenue
# 18           9         2  Canned Soda           [Sprite]     $2.18               $2.18 $2.18
# 51          23         2  Canned Soda     [Mountain Dew]     $2.18               $2.18 $2.18
# 162         73         2  Canned Soda        [Diet Coke]     $2.18               $2.18 $2.18
# 171         76         2  Canned Soda  [Diet Dr. Pepper]     $2.18               $2.18 $2.18
# 350        150         2  Canned Soda        [Diet Coke]     $2.18               $2.18 $2.18
# 352        151         2  Canned Soda        [Coca Cola]     $2.18               $2.18 $2.18
# 698        287         2  Canned Soda        [Coca Cola]     $2.18               $2.18 $2.18
# 700        288         2  Canned Soda        [Coca Cola]     $2.18               $2.18 $2.18
# 909        376         2  Canned Soda     [Mountain Dew]     $2.18               $2.18 $2.18
# ...

# %%
count = filtered_table.shape[0]
count
# Out:
# 20
